# %% [markdown]
# <a href="https://colab.research.google.com/github/possomartin/Notebooks/blob/main/Movies_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
MovieDataSet = pd.read_csv("https://raw.githubusercontent.com/possomartin/Movie-Analytics/main/Visualization_MFG_sample.csv");
MovieArray = MovieDataSet.to_numpy()


print(MovieDataSet)

plt.figure(figsize=(7,7))
plt.plot(MovieDataSet['grossboxoffice'], MovieDataSet['estmated_budget'])
plt.xlabel('Grossbox Office')
plt.ylabel('Estimated Budget')
plt.figure(figsize=(7,7))
plt.plot(MovieDataSet['grossboxoffice'], MovieDataSet['movie_length'])
plt.xlabel('Grossbox Office')
plt.ylabel('Movie Length')
plt.figure(figsize=(7,7))
plt.bar(MovieDataSet['grossboxoffice'], MovieDataSet['movie_length'])
plt.show()
# Out:
#      ourid  release_date  ...  movie_length  Unnamed: 40
# 0    10592         39423  ...            85          NaN
# 1    12331         37554  ...           122          NaN
# 2    11041         38814  ...             0          NaN
# 3    10734         39906  ...            80          NaN
# 4    11446         38212  ...            92          NaN
# ..     ...           ...  ...           ...          ...
# 691  12332         37244  ...           178          NaN
# 692  11519         38674  ...           157          NaN
# 693  12248         37608  ...           179          NaN
# 694  12009         37211  ...           152          NaN
# 695  10744         39647  ...           152          NaN
#
# [696 rows x 41 columns]
